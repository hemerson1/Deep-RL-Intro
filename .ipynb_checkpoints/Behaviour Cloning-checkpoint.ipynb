# %%
## Behaviour Cloning Model ##################################################################################

# Use Behavioural Cloning to play catcher game from PLE

###################################################################################################################

# %%
import import_ipynb
import numpy as np
from ple import PLE
import pygame
import pickle 
import os.path
from datetime import datetime
from sklearn.preprocessing import OneHotEncoder, LabelEncoder
from sklearn.model_selection import train_test_split
import tensorflow as tf
from tensorflow.keras import Sequential
from tensorflow.keras.layers import Reshape, Dense 
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.models import load_model
from tensorflow.keras.initializers import HeNormal, GlorotNormal

from game import Catcher
from utils import *

#########################################################################
# VARIABLES 

# WORKFLOW
IS_TRAINING = False

# ENVIRONMENT
RENDER = True
NB_FRAMES = 10000
WAIT = 30 

# TRAINING
SAVE = True # True to save user data file
TRAIN = True # True to train the model on data collected
SELECTING = False # True if want to load a file different to the one collected
CUSTOM_FILE = './Expert Data/2020-12-30_18-04-58.txt' # The custom file name 
RESUME = True # True if you want to load the current model and retrain

# MODEL
EPOCHS = 10
LEARNING_RATE = 0.0001

#########################################################################

# SUMMARY #############################################################
# INPUTS: 
    # player x positon
    # player velocity
    # fruits x-position
    # fruits y-position
# OUTPUTS: 
    # prob of staying
    # prob of turning right 
    # prob of turning left    
######################################################################

#---------------------------------------------------------------------
# Want to match the current state to the action
class Behavioural_Cloning():
        
    def __init__(self, lr=LEARNING_RATE):
        self.lr = lr
        self.model = self.create_model()        
        
    def create_model(self):
        model = Sequential()
        model.add(Reshape((4,), input_shape=(4,1)))
        model.add(Dense(100, activation='relu', kernel_initializer=HeNormal(seed=2)))
        model.add(Dense(25, activation='relu', kernel_initializer=HeNormal(seed=2)))
        model.add(Dense(3, activation='softmax', kernel_initializer=GlorotNormal(seed=2)))
        model.compile(optimizer=Adam(learning_rate=self.lr), 
                       metrics=["accuracy"],
                       loss="categorical_crossentropy")
        
        return model
    
# -----------------------------------------------------------------------


# Learning from the expert policy maker
if IS_TRAINING:
    
    # Initialise the environment
    pygame.init()
    game = Catcher(width=512, height=512)
    game.rng = np.random.RandomState(24)
    game.clock = pygame.time.Clock()
    game.screen = pygame.display.set_mode(game.getScreenDims(), 0, 32) # set screen to centre    
    game.init()
    
    inputs = []
    outputs = []
    
    for iter in range(NB_FRAMES):
        
        # sets the wait between frames
        dt = game.clock.tick_busy_loop(WAIT)
        
        state = game.getGameState()
        action = game.getKeyPressed()        
        
        # take a step 
        game.step(dt)
        pygame.display.update() 
        
        # save the data to the lists 
        inputs.append(state)
        outputs.append(action)
        
        if game.game_over(): 
            pygame.quit()
            
            # how many rounds did the user run for? 
            print('Ran for: ' + str(iter) + ' frames' )
            
            dt_string = None            
            if SAVE:             
                # get current time + date 
                now = datetime.now()
                dt_string = now.strftime("%Y-%m-%d_%H-%M-%S")

                # save the file to pickle
                with open("./Expert Data/" + dt_string + ".txt", "wb") as data1:
                    pickle.dump([inputs, outputs], data1)
            
            if TRAIN and SAVE:
                print('Training the model')
                
                if SELECTING:
                    dataSource = CUSTOM_FILE                  
                
                else:     
                    dataSource = './Expert Data/' + dt_string + '.txt' 
                 
                # Unpickling
                with open(dataSource, "rb") as data1:   
                    expert_data = pickle.load(data1)

                # Format the dataset     
                inputs = expert_data[0] # the inputs 
                outputs = np.array(expert_data[1]).astype(str) # the outputs
                
                # get the split of values
                unique, counts = np.unique(outputs, return_counts=True)
                print(dict(zip(unique, counts)))
                
                # One hot encode data    
                label_encoder = LabelEncoder()
                onehot_encoder = OneHotEncoder(sparse=False)    
                integer_encoded = label_encoder.fit_transform(outputs)
                integer_encoded = integer_encoded.reshape(len(integer_encoded), 1)    
                y = onehot_encoder.fit_transform(integer_encoded).reshape(3, len(integer_encoded))

                # import from utils -> perform preprocessing
                X = process_states(inputs)

                # split the data into training, validation and testing data
                # test: 20%, train: 60%, validation: 20%
                # reshaped again to utilise spliting function correctly
                X_train, X_test, y_train, y_test = train_test_split(X.reshape(X.shape[1], 4), y.reshape(y.shape[1], 3), test_size=0.2, random_state=42) 
                X_train, X_val, y_train, y_val = train_test_split(X_train, y_train, test_size=0.25, random_state=42)
                
                # load in the correct model
                if os.path.isfile('model_imitation.h5') and RESUME:
                    model = load_model('model_imitation.h5')
                else:
                    model = Behavioural_Cloning().model  
                    
                # add some class weights
                class_weight = {0: 1., 1: 25., 2: 25.}

                # train the model using the selected data source 
                train_res = model.fit(X_train, y_train,
                                      validation_data=(X_val, y_val),
                                      epochs=EPOCHS,
                                      class_weight=class_weight,
                                      verbose=2) 
                
                test_res = model.evaluate(X_test, y_test,
                                          verbose=2)  
                
                print('Training Complete')
                
                # Save the model                
                model.save('model_imitation.h5')
                
                print('Model Saved')
                
            break          
           
        
        
# Testing the apprentice policy maker
else:
    
    # Initialise the environment
    pygame.init()
    game = Catcher(width=512, height=512)
    game.rng = np.random.RandomState(1)
    game.clock = pygame.time.Clock()
    game.screen = pygame.display.set_mode(game.getScreenDims(), 0, 32) # set screen to centre   
    env = PLE(game, fps=60, display_screen=RENDER)
    env.init()
    
    # intialise the model
    model = load_model('model_imitation.h5')
    
    # get the possible actions
    possible_actions = game.actions 
    
    # for some reason breaks without this    
    env.act(env.NOOP)
    
    for iter in range(NB_FRAMES):
        
        # sets the wait between frames
        dt = game.clock.tick_busy_loop(WAIT)
        
        # is the game over?
        if env.game_over(): 
            pygame.quit()
            
            # how many rounds did the user run for?             
            print('Ran for: ' + str(iter) + ' frames' )    
            
            break        
        
        # get the current game state
        state = env.getGameState()
        
        # decide the current action 
        # state must be in [] for iteration in process states  
        # using model instead of model.predict is so much faster!
        action_prob = model(process_states([state]).reshape(1, len(state)), training=False) 
        selected_action = np.argmax(action_prob[0])
        
        env.act(possible_actions[selected_action])
# Out:
# {'player_x': 205, 'player_vel': 0.0, 'fruit_x': 434, 'fruit_y': -22}
# {'player_x': 214, 'player_vel': 9.6768, 'fruit_x': 434, 'fruit_y': -13}
# {'player_x': 232, 'player_vel': 18.385920000000002, 'fruit_x': 434, 'fruit_y': -4}
# {'player_x': 248, 'player_vel': 16.547328000000004, 'fruit_x': 434, 'fruit_y': 4}
# {'player_x': 262, 'player_vel': 14.892595200000004, 'fruit_x': 434, 'fruit_y': 12}
# {'player_x': 275, 'player_vel': 13.403335680000003, 'fruit_x': 434, 'fruit_y': 20}
# {'player_x': 287, 'player_vel': 12.063002112000003, 'fruit_x': 434, 'fruit_y': 28}
# {'player_x': 297, 'player_vel': 10.856701900800003, 'fruit_x': 434, 'fruit_y': 36}
# {'player_x': 306, 'player_vel': 9.771031710720003, 'fruit_x': 434, 'fruit_y': 44}
# {'player_x': 314, 'player_vel': 8.793928539648002, 'fruit_x': 434, 'fruit_y': 52}
# {'player_x': 312, 'player_vel': -1.7622643143167989, 'fruit_x': 434, 'fruit_y': 60}
# {'player_x': 300, 'player_vel': -11.262837882885119, 'fruit_x': 434, 'fruit_y': 68}
# {'player_x': 299, 'player_vel': -0.4597540945966065, 'fruit_x': 434, 'fruit_y': 76}
# {'player_x': 308, 'player_vel': 9.263021314863055, 'fruit_x': 434, 'fruit_y': 84}
# {'player_x': 326, 'player_vel': 18.01351918337675, 'fruit_x': 434, 'fruit_y': 92}
# {'player_x': 332, 'player_vel': 6.535367265039075, 'fruit_x': 434, 'fruit_y': 100}
# {'player_x': 328, 'player_vel': -3.794969461464833, 'fruit_x': 434, 'fruit_y': 108}
# {'player_x': 314, 'player_vel': -13.092272515318351, 'fruit_x': 434, 'fruit_y': 116}
# {'player_x': 311, 'player_vel': -2.106245263786515, 'fruit_x': 434, 'fruit_y': 124}
# {'player_x': 318, 'player_vel': 7.781179262592136, 'fruit_x': 434, 'fruit_y': 132}
# {'player_x': 334, 'player_vel': 16.679861336332923, 'fruit_x': 434, 'fruit_y': 140}
# {'player_x': 339, 'player_vel': 5.33507520269963, 'fruit_x': 434, 'fruit_y': 148}
# {'player_x': 353, 'player_vel': 14.478367682429667, 'fruit_x': 434, 'fruit_y': 156}
# {'player_x': 356, 'player_vel': 3.3537309141866998, 'fruit_x': 434, 'fruit_y': 164}
# {'player_x': 349, 'player_vel': -6.65844217723197, 'fruit_x': 434, 'fruit_y': 172}
# {'player_x': 352, 'player_vel': 3.6842020404912272, 'fruit_x': 434, 'fruit_y': 180}
# {'player_x': 364, 'player_vel': 12.992581836442106, 'fruit_x': 434, 'fruit_y': 188}
# {'player_x': 366, 'player_vel': 2.016523652797895, 'fruit_x': 434, 'fruit_y': 196}
# {'player_x': 377, 'player_vel': 11.491671287518107, 'fruit_x': 434, 'fruit_y': 204}
# {'player_x': 377, 'player_vel': 0.665704158766296, 'fruit_x': 434, 'fruit_y': 212}
# {'player_x': 387, 'player_vel': 10.275933742889666, 'fruit_x': 434, 'fruit_y': 220}
# {'player_x': 386, 'player_vel': -0.4284596313993008, 'fruit_x': 434, 'fruit_y': 228}
# {'player_x': 375, 'player_vel': -10.062413668259373, 'fruit_x': 434, 'fruit_y': 236}
# {'player_x': 375, 'player_vel': 0.6206276985665653, 'fruit_x': 434, 'fruit_y': 244}
# {'player_x': 385, 'player_vel': 10.23536492870991, 'fruit_x': 434, 'fruit_y': 252}
# {'player_x': 403, 'player_vel': 18.888628435838918, 'fruit_x': 434, 'fruit_y': 260}
# {'player_x': 410, 'player_vel': 0.0, 'fruit_x': 434, 'fruit_y': 268}
# {'player_x': 400, 'player_vel': -9.6768, 'fruit_x': 434, 'fruit_y': 276}
# {'player_x': 400, 'player_vel': 0.9676800000000005, 'fruit_x': 434, 'fruit_y': 284}
# {'player_x': 410, 'player_vel': 0.0, 'fruit_x': 434, 'fruit_y': 292}
# {'player_x': 400, 'player_vel': -9.6768, 'fruit_x': 434, 'fruit_y': 300}
# {'player_x': 400, 'player_vel': 0.9676800000000005, 'fruit_x': 434, 'fruit_y': 308}
# {'player_x': 410, 'player_vel': 0.0, 'fruit_x': 434, 'fruit_y': 316}
# {'player_x': 400, 'player_vel': -9.6768, 'fruit_x': 434, 'fruit_y': 324}
# {'player_x': 400, 'player_vel': 0.9676800000000005, 'fruit_x': 434, 'fruit_y': 332}
# {'player_x': 410, 'player_vel': 0.0, 'fruit_x': 434, 'fruit_y': 340}
# {'player_x': 400, 'player_vel': -9.6768, 'fruit_x': 434, 'fruit_y': 348}
# {'player_x': 381, 'player_vel': -18.385920000000002, 'fruit_x': 434, 'fruit_y': 356}
# {'player_x': 374, 'player_vel': -6.870528000000002, 'fruit_x': 434, 'fruit_y': 364}
# {'player_x': 377, 'player_vel': 3.493324799999999, 'fruit_x': 434, 'fruit_y': 372}
# {'player_x': 389, 'player_vel': 12.820792319999999, 'fruit_x': 434, 'fruit_y': 380}
# {'player_x': 390, 'player_vel': 1.8619130879999986, 'fruit_x': 434, 'fruit_y': 388}
# {'player_x': 381, 'player_vel': -8.001078220800002, 'fruit_x': 434, 'fruit_y': 396}
# {'player_x': 364, 'player_vel': -16.877770398720003, 'fruit_x': 434, 'fruit_y': 404}
# {'player_x': 358, 'player_vel': -5.513193358848002, 'fruit_x': 434, 'fruit_y': 412}
# {'player_x': 362, 'player_vel': 4.714925977036799, 'fruit_x': 434, 'fruit_y': 420}
# {'player_x': 375, 'player_vel': 13.92023337933312, 'fruit_x': 434, 'fruit_y': 428}
# {'player_x': 387, 'player_vel': 12.528210041399808, 'fruit_x': 434, 'fruit_y': 436}
# {'player_x': 388, 'player_vel': 1.5985890372598264, 'fruit_x': 434, 'fruit_y': 444}
# {'player_x': 379, 'player_vel': -8.238069866466157, 'fruit_x': 434, 'fruit_y': 452}
# {'player_x': 361, 'player_vel': -17.091062879819543, 'fruit_x': 434, 'fruit_y': 460}
# {'player_x': 345, 'player_vel': -15.38195659183759, 'fruit_x': 434, 'fruit_y': 468}
# {'player_x': 331, 'player_vel': -13.843760932653831, 'fruit_x': 434, 'fruit_y': 476}
# {'player_x': 318, 'player_vel': -12.459384839388449, 'fruit_x': 434, 'fruit_y': 484}
# {'player_x': 316, 'player_vel': -1.536646355449603, 'fruit_x': 434, 'fruit_y': 492}
# {'player_x': 324, 'player_vel': 8.293818280095358, 'fruit_x': 434, 'fruit_y': 500}
# {'player_x': 331, 'player_vel': 7.464436452085823, 'fruit_x': 434, 'fruit_y': 508}
# {'player_x': 337, 'player_vel': 6.717992806877241, 'fruit_x': 434, 'fruit_y': 516}
# {'player_x': 343, 'player_vel': 6.046193526189517, 'fruit_x': 341, 'fruit_y': -115}
# {'player_x': 348, 'player_vel': 5.441574173570566, 'fruit_x': 341, 'fruit_y': -106}
# {'player_x': 352, 'player_vel': 4.897416756213509, 'fruit_x': 341, 'fruit_y': -97}
# {'player_x': 356, 'player_vel': 4.407675080592159, 'fruit_x': 341, 'fruit_y': -88}
# {'player_x': 359, 'player_vel': 3.9669075725329432, 'fruit_x': 341, 'fruit_y': -79}
# {'player_x': 352, 'player_vel': -6.106583184720352, 'fruit_x': 341, 'fruit_y': -70}
# {'player_x': 336, 'player_vel': -15.172724866248318, 'fruit_x': 341, 'fruit_y': -61}
# {'player_x': 312, 'player_vel': -23.332252379623487, 'fruit_x': 341, 'fruit_y': -52}
# {'player_x': 281, 'player_vel': -30.675827141661138, 'fruit_x': 341, 'fruit_y': -43}
# {'player_x': 243, 'player_vel': -37.28504442749503, 'fruit_x': 341, 'fruit_y': -34}
# {'player_x': 209, 'player_vel': -33.55653998474553, 'fruit_x': 341, 'fruit_y': -25}
# {'player_x': 178, 'player_vel': -30.200885986270976, 'fruit_x': 341, 'fruit_y': -16}
# {'player_x': 160, 'player_vel': -17.503997387643878, 'fruit_x': 341, 'fruit_y': -7}
# {'player_x': 153, 'player_vel': -6.07679764887949, 'fruit_x': 341, 'fruit_y': 1}
# {'player_x': 157, 'player_vel': 4.20768211600846, 'fruit_x': 341, 'fruit_y': 9}
# {'player_x': 170, 'player_vel': 13.463713904407614, 'fruit_x': 341, 'fruit_y': 17}
# {'player_x': 191, 'player_vel': 21.794142513966854, 'fruit_x': 341, 'fruit_y': 25}
# {'player_x': 220, 'player_vel': 29.29152826257017, 'fruit_x': 341, 'fruit_y': 33}
# {'player_x': 246, 'player_vel': 26.362375436313155, 'fruit_x': 341, 'fruit_y': 41}
# {'player_x': 269, 'player_vel': 23.72613789268184, 'fruit_x': 341, 'fruit_y': 49}
# {'player_x': 280, 'player_vel': 11.676724103413656, 'fruit_x': 341, 'fruit_y': 57}
# {'player_x': 280, 'player_vel': 0.8322516930722902, 'fruit_x': 341, 'fruit_y': 65}
# {'player_x': 271, 'player_vel': -8.92777347623494, 'fruit_x': 341, 'fruit_y': 73}
# {'player_x': 253, 'player_vel': -17.71179612861145, 'fruit_x': 341, 'fruit_y': 81}
# {'player_x': 227, 'player_vel': -25.617416515750303, 'fruit_x': 341, 'fruit_y': 89}
# {'player_x': 213, 'player_vel': -13.378874864175273, 'fruit_x': 341, 'fruit_y': 97}
# {'player_x': 210, 'player_vel': -2.3641873777577453, 'fruit_x': 341, 'fruit_y': 105}
# {'player_x': 217, 'player_vel': 7.549031360018029, 'fruit_x': 341, 'fruit_y': 113}
# {'player_x': 233, 'player_vel': 16.470928224016227, 'fruit_x': 341, 'fruit_y': 121}
# {'player_x': 257, 'player_vel': 24.500635401614606, 'fruit_x': 341, 'fruit_y': 129}
# {'player_x': 288, 'player_vel': 31.727371861453143, 'fruit_x': 341, 'fruit_y': 137}
# {'player_x': 306, 'player_vel': 18.877834675307827, 'fruit_x': 341, 'fruit_y': 145}
# {'player_x': 313, 'player_vel': 7.313251207777045, 'fruit_x': 341, 'fruit_y': 153}
# {'player_x': 309, 'player_vel': -3.0948739130006606, 'fruit_x': 341, 'fruit_y': 161}
# {'player_x': 296, 'player_vel': -12.462186521700595, 'fruit_x': 341, 'fruit_y': 169}
# {'player_x': 294, 'player_vel': -1.5391678695305346, 'fruit_x': 341, 'fruit_y': 177}
# {'player_x': 302, 'player_vel': 8.291548917422519, 'fruit_x': 341, 'fruit_y': 185}
# {'player_x': 319, 'player_vel': 17.13919402568027, 'fruit_x': 341, 'fruit_y': 193}
# {'player_x': 324, 'player_vel': 5.748474623112241, 'fruit_x': 341, 'fruit_y': 201}
# {'player_x': 319, 'player_vel': -4.503172839198984, 'fruit_x': 341, 'fruit_y': 209}
# {'player_x': 305, 'player_vel': -13.729655555279086, 'fruit_x': 341, 'fruit_y': 217}
# {'player_x': 302, 'player_vel': -2.6798899997511767, 'fruit_x': 341, 'fruit_y': 225}
# {'player_x': 309, 'player_vel': 7.2648990002239415, 'fruit_x': 341, 'fruit_y': 233}
# {'player_x': 325, 'player_vel': 16.21520910020155, 'fruit_x': 341, 'fruit_y': 241}
# {'player_x': 329, 'player_vel': 4.916888190181396, 'fruit_x': 341, 'fruit_y': 249}
# {'player_x': 323, 'player_vel': -5.251600628836744, 'fruit_x': 341, 'fruit_y': 257}
# {'player_x': 308, 'player_vel': -14.40324056595307, 'fruit_x': 341, 'fruit_y': 265}
# {'player_x': 304, 'player_vel': -3.286116509357762, 'fruit_x': 341, 'fruit_y': 273}
# {'player_x': 310, 'player_vel': 6.719295141578015, 'fruit_x': 341, 'fruit_y': 281}
# {'player_x': 325, 'player_vel': 15.724165627420213, 'fruit_x': 341, 'fruit_y': 289}
# {'player_x': 329, 'player_vel': 4.474949064678191, 'fruit_x': 341, 'fruit_y': 297}
# {'player_x': 323, 'player_vel': -5.6493458417896285, 'fruit_x': 341, 'fruit_y': 305}
# {'player_x': 308, 'player_vel': -14.761211257610665, 'fruit_x': 341, 'fruit_y': 313}
# {'player_x': 285, 'player_vel': -22.961890131849596, 'fruit_x': 341, 'fruit_y': 321}
# {'player_x': 274, 'player_vel': -10.988901118664636, 'fruit_x': 341, 'fruit_y': 329}
# {'player_x': 273, 'player_vel': -0.21321100679817154, 'fruit_x': 341, 'fruit_y': 337}
# {'player_x': 282, 'player_vel': 9.484910093881647, 'fruit_x': 341, 'fruit_y': 345}
# {'player_x': 290, 'player_vel': 8.536419084493483, 'fruit_x': 341, 'fruit_y': 353}
# {'player_x': 297, 'player_vel': 7.682777176044135, 'fruit_x': 341, 'fruit_y': 361}
# {'player_x': 303, 'player_vel': 6.914499458439721, 'fruit_x': 341, 'fruit_y': 369}
# {'player_x': 299, 'player_vel': -3.453750487404252, 'fruit_x': 341, 'fruit_y': 377}
# {'player_x': 286, 'player_vel': -12.785175438663828, 'fruit_x': 341, 'fruit_y': 385}
# {'player_x': 274, 'player_vel': -11.506657894797446, 'fruit_x': 341, 'fruit_y': 393}
# {'player_x': 263, 'player_vel': -10.355992105317702, 'fruit_x': 341, 'fruit_y': 401}
# {'player_x': 253, 'player_vel': -9.320392894785932, 'fruit_x': 341, 'fruit_y': 409}
# {'player_x': 244, 'player_vel': -8.388353605307339, 'fruit_x': 341, 'fruit_y': 417}
# {'player_x': 236, 'player_vel': -7.549518244776605, 'fruit_x': 341, 'fruit_y': 425}
# {'player_x': 229, 'player_vel': -6.794566420298945, 'fruit_x': 341, 'fruit_y': 433}
# {'player_x': 232, 'player_vel': 3.5616902217309505, 'fruit_x': 341, 'fruit_y': 441}
# {'player_x': 235, 'player_vel': 3.2055211995578556, 'fruit_x': 341, 'fruit_y': 449}
# {'player_x': 237, 'player_vel': 2.88496907960207, 'fruit_x': 341, 'fruit_y': 457}
# {'player_x': 239, 'player_vel': 2.5964721716418633, 'fruit_x': 341, 'fruit_y': 465}
# {'player_x': 241, 'player_vel': 2.336824954477677, 'fruit_x': 341, 'fruit_y': 473}
# {'player_x': 243, 'player_vel': 2.1031424590299093, 'fruit_x': 341, 'fruit_y': 481}
# {'player_x': 244, 'player_vel': 1.8928282131269183, 'fruit_x': 341, 'fruit_y': 489}
# {'player_x': 245, 'player_vel': 1.7035453918142265, 'fruit_x': 341, 'fruit_y': 497}
# {'player_x': 246, 'player_vel': 1.533190852632804, 'fruit_x': 341, 'fruit_y': 505}
# {'player_x': 247, 'player_vel': 1.3798717673695235, 'fruit_x': 341, 'fruit_y': 513}
# {'player_x': 248, 'player_vel': 1.2418845906325713, 'fruit_x': 217, 'fruit_y': -239}
# {'player_x': 249, 'player_vel': 1.1176961315693141, 'fruit_x': 217, 'fruit_y': -230}
# {'player_x': 250, 'player_vel': 1.0059265184123827, 'fruit_x': 217, 'fruit_y': -221}
# {'player_x': 250, 'player_vel': 0.9053338665711445, 'fruit_x': 217, 'fruit_y': -212}
# {'player_x': 250, 'player_vel': 0.81480047991403, 'fruit_x': 217, 'fruit_y': -203}
# {'player_x': 250, 'player_vel': 0.7333204319226271, 'fruit_x': 217, 'fruit_y': -194}
# {'player_x': 250, 'player_vel': 0.6599883887303644, 'fruit_x': 217, 'fruit_y': -185}
# {'player_x': 250, 'player_vel': 0.593989549857328, 'fruit_x': 217, 'fruit_y': -176}
# {'player_x': 250, 'player_vel': 0.5345905948715952, 'fruit_x': 217, 'fruit_y': -167}
# {'player_x': 250, 'player_vel': 0.4811315353844357, 'fruit_x': 217, 'fruit_y': -158}
# {'player_x': 250, 'player_vel': 0.4330183818459921, 'fruit_x': 217, 'fruit_y': -149}
# {'player_x': 250, 'player_vel': 0.3897165436613929, 'fruit_x': 217, 'fruit_y': -140}
# {'player_x': 250, 'player_vel': 0.3507448892952536, 'fruit_x': 217, 'fruit_y': -131}
# {'player_x': 250, 'player_vel': 0.31567040036572824, 'fruit_x': 217, 'fruit_y': -122}
# {'player_x': 250, 'player_vel': 0.28410336032915545, 'fruit_x': 217, 'fruit_y': -113}
# {'player_x': 250, 'player_vel': 0.2556930242962399, 'fruit_x': 217, 'fruit_y': -104}
# {'player_x': 250, 'player_vel': 0.23012372186661592, 'fruit_x': 217, 'fruit_y': -95}
# {'player_x': 250, 'player_vel': 0.20711134967995434, 'fruit_x': 217, 'fruit_y': -86}
# {'player_x': 250, 'player_vel': 0.18640021471195892, 'fruit_x': 217, 'fruit_y': -77}
# {'player_x': 250, 'player_vel': 0.16776019324076302, 'fruit_x': 217, 'fruit_y': -68}
# {'player_x': 250, 'player_vel': 0.15098417391668673, 'fruit_x': 217, 'fruit_y': -59}
# {'player_x': 240, 'player_vel': -9.540914243474983, 'fruit_x': 217, 'fruit_y': -50}
# {'player_x': 221, 'player_vel': -18.263622819127484, 'fruit_x': 217, 'fruit_y': -41}
# {'player_x': 194, 'player_vel': -26.114060537214737, 'fruit_x': 217, 'fruit_y': -32}
# {'player_x': 160, 'player_vel': -33.17945448349327, 'fruit_x': 217, 'fruit_y': -23}
# {'player_x': 120, 'player_vel': -39.538309035143946, 'fruit_x': 217, 'fruit_y': -14}
# {'player_x': 94, 'player_vel': -25.90767813162955, 'fruit_x': 217, 'fruit_y': -5}
# {'player_x': 80, 'player_vel': -13.640110318466593, 'fruit_x': 217, 'fruit_y': 3}
# {'player_x': 77, 'player_vel': -2.599299286619934, 'fruit_x': 217, 'fruit_y': 11}
# {'player_x': 84, 'player_vel': 7.337430642042061, 'fruit_x': 217, 'fruit_y': 19}
# {'player_x': 100, 'player_vel': 16.280487577837857, 'fruit_x': 217, 'fruit_y': 27}
# {'player_x': 124, 'player_vel': 24.32923882005407, 'fruit_x': 217, 'fruit_y': 35}
# {'player_x': 155, 'player_vel': 31.57311493804866, 'fruit_x': 217, 'fruit_y': 43}
# {'player_x': 183, 'player_vel': 28.415803444243796, 'fruit_x': 217, 'fruit_y': 51}
# {'player_x': 198, 'player_vel': 15.897423099819418, 'fruit_x': 217, 'fruit_y': 59}
# {'player_x': 202, 'player_vel': 4.630880789837476, 'fruit_x': 217, 'fruit_y': 67}
# {'player_x': 196, 'player_vel': -5.509007289146273, 'fruit_x': 217, 'fruit_y': 75}
# {'player_x': 181, 'player_vel': -14.634906560231647, 'fruit_x': 217, 'fruit_y': 83}
# {'player_x': 158, 'player_vel': -22.848215904208484, 'fruit_x': 217, 'fruit_y': 91}
# {'player_x': 147, 'player_vel': -10.886594313787635, 'fruit_x': 217, 'fruit_y': 99}
# {'player_x': 146, 'player_vel': -0.12113488240887059, 'fruit_x': 217, 'fruit_y': 107}
# {'player_x': 155, 'player_vel': 9.567778605832016, 'fruit_x': 217, 'fruit_y': 115}
# {'player_x': 173, 'player_vel': 18.287800745248816, 'fruit_x': 217, 'fruit_y': 123}
# {'player_x': 199, 'player_vel': 26.135820670723938, 'fruit_x': 217, 'fruit_y': 131}
# {'player_x': 212, 'player_vel': 13.845438603651543, 'fruit_x': 217, 'fruit_y': 139}
# {'player_x': 214, 'player_vel': 2.784094743286388, 'fruit_x': 217, 'fruit_y': 147}
# {'player_x': 206, 'player_vel': -7.171114731042251, 'fruit_x': 217, 'fruit_y': 155}
# {'player_x': 189, 'player_vel': -16.130803257938027, 'fruit_x': 217, 'fruit_y': 163}
# {'player_x': 184, 'player_vel': -4.840922932144224, 'fruit_x': 217, 'fruit_y': 171}
# {'player_x': 189, 'player_vel': 5.319969361070199, 'fruit_x': 217, 'fruit_y': 179}
# {'player_x': 203, 'player_vel': 14.46477242496318, 'fruit_x': 217, 'fruit_y': 187}
# {'player_x': 206, 'player_vel': 3.341495182466861, 'fruit_x': 217, 'fruit_y': 195}
# {'player_x': 199, 'player_vel': -6.669454335779825, 'fruit_x': 217, 'fruit_y': 203}
# {'player_x': 183, 'player_vel': -15.679308902201845, 'fruit_x': 217, 'fruit_y': 211}
# {'player_x': 168, 'player_vel': -14.11137801198166, 'fruit_x': 217, 'fruit_y': 219}
# {'player_x': 164, 'player_vel': -3.0234402107834937, 'fruit_x': 217, 'fruit_y': 227}
# {'player_x': 170, 'player_vel': 6.955703810294857, 'fruit_x': 217, 'fruit_y': 235}
# {'player_x': 176, 'player_vel': 6.260133429265371, 'fruit_x': 217, 'fruit_y': 243}
# {'player_x': 181, 'player_vel': 5.634120086338834, 'fruit_x': 217, 'fruit_y': 251}
# {'player_x': 186, 'player_vel': 5.070708077704951, 'fruit_x': 217, 'fruit_y': 259}
# {'player_x': 190, 'player_vel': 4.563637269934456, 'fruit_x': 217, 'fruit_y': 267}
# {'player_x': 194, 'player_vel': 4.1072735429410105, 'fruit_x': 217, 'fruit_y': 275}
# {'player_x': 188, 'player_vel': -5.980253811353092, 'fruit_x': 217, 'fruit_y': 283}
# {'player_x': 182, 'player_vel': -5.382228430217783, 'fruit_x': 217, 'fruit_y': 291}
# {'player_x': 177, 'player_vel': -4.844005587196005, 'fruit_x': 217, 'fruit_y': 299}
# {'player_x': 172, 'player_vel': -4.3596050284764045, 'fruit_x': 217, 'fruit_y': 307}
# {'player_x': 168, 'player_vel': -3.923644525628764, 'fruit_x': 217, 'fruit_y': 315}
# {'player_x': 164, 'player_vel': -3.5312800730658878, 'fruit_x': 217, 'fruit_y': 323}
# {'player_x': 160, 'player_vel': -3.178152065759299, 'fruit_x': 217, 'fruit_y': 331}
# {'player_x': 157, 'player_vel': -2.8603368591833696, 'fruit_x': 217, 'fruit_y': 339}
# {'player_x': 154, 'player_vel': -2.5743031732650326, 'fruit_x': 217, 'fruit_y': 347}
# {'player_x': 151, 'player_vel': -2.3168728559385294, 'fruit_x': 217, 'fruit_y': 355}
# {'player_x': 148, 'player_vel': -2.0851855703446764, 'fruit_x': 217, 'fruit_y': 363}
# {'player_x': 146, 'player_vel': -1.8766670133102088, 'fruit_x': 217, 'fruit_y': 371}
# {'player_x': 144, 'player_vel': -1.6890003119791879, 'fruit_x': 217, 'fruit_y': 379}
# {'player_x': 142, 'player_vel': -1.5201002807812691, 'fruit_x': 217, 'fruit_y': 387}
# {'player_x': 140, 'player_vel': -1.3680902527031422, 'fruit_x': 217, 'fruit_y': 395}
# {'player_x': 138, 'player_vel': -1.231281227432828, 'fruit_x': 217, 'fruit_y': 403}
# {'player_x': 136, 'player_vel': -1.1081531046895452, 'fruit_x': 217, 'fruit_y': 411}
# {'player_x': 135, 'player_vel': -0.9973377942205907, 'fruit_x': 217, 'fruit_y': 419}
# {'player_x': 134, 'player_vel': -0.8976040147985316, 'fruit_x': 217, 'fruit_y': 427}
# {'player_x': 133, 'player_vel': -0.8078436133186785, 'fruit_x': 217, 'fruit_y': 435}
# {'player_x': 132, 'player_vel': -0.7270592519868107, 'fruit_x': 217, 'fruit_y': 443}
# {'player_x': 131, 'player_vel': -0.6543533267881296, 'fruit_x': 217, 'fruit_y': 451}
# {'player_x': 130, 'player_vel': -0.5889179941093167, 'fruit_x': 217, 'fruit_y': 459}
# {'player_x': 129, 'player_vel': -0.530026194698385, 'fruit_x': 217, 'fruit_y': 467}
# {'player_x': 128, 'player_vel': -0.4770235752285465, 'fruit_x': 217, 'fruit_y': 475}
# {'player_x': 127, 'player_vel': -0.42932121770569187, 'fruit_x': 217, 'fruit_y': 483}
# {'player_x': 126, 'player_vel': -0.3863890959351227, 'fruit_x': 217, 'fruit_y': 491}
# {'player_x': 125, 'player_vel': -0.3477501863416105, 'fruit_x': 217, 'fruit_y': 499}
# {'player_x': 124, 'player_vel': -0.31297516770744943, 'fruit_x': 217, 'fruit_y': 507}
# {'player_x': 123, 'player_vel': -0.2816776509367045, 'fruit_x': 217, 'fruit_y': 515}
# Ran for: 238 frames
