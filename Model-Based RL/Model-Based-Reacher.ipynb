# %%
# Model-Based RL - Using a model-based random shooting algorithm to solve HalfCheetah

# Code was used from: https://github.com/ZhengXinyue/Model-Predictive-Control/blob/master/Learning_MPC/Learning_MPC_Pendulum.py
# Got some guidance from the HW: http://rail.eecs.berkeley.edu/deeprlcourse/static/homeworks/hw4.pdf 

### SANITY TEST ##############################################################

# GOAL: ~ 25 acheived in benchmark papers

# ENVIRONMENT SUMMARY: -> Reacher-v2
# -> Continuous action space

# Observation -> 11 items
#    cos(theta) (first joint)        
#    cos(theta) (second joint)        
#    sin(theta) (first joint)        
#    sin(theta) (second joint)        
#    qpos (the x coordinate of the target)        
#    qpos (the y coordinate of the target)        
#    qvel (the velocity of the fingertip in the x direction)        
#    qvel (the velocity of the fingertip in the y direction)        
#    the x-axis component of the vector from the target to the fingertip        
#    the y-axis component of the vector from the target to the fingertip        
#    the z-axis component of the vector from the target to the fingertip    

# Action -> 2 items
# range from -1 to 1
# most likely correspond to torque of two joints

# Reward -> 1 item

### MAIN #######################################################################

# ENVIRONMENT SUMMARY: -> Cheetah-v2
# -> Continuous action space

# Observation -> 17 items

# Action -> 6 items

# Reward -> 1 item

#################################################################################

import os
import random
import math
import gym
import numpy as np
from collections import deque
from tensorflow.keras.models import Model, load_model
from tensorflow.keras.layers import Input, Dense, Flatten
from tensorflow.keras.optimizers import Adam
import pickle

# TO DO ##########################################################################

# reduce the number of features 
# perform some scaling or normalising


# NOTES ##########################################################################

# the principle is that: more rollouts and longer horizon will make better performance.

##################################################################################

# Neural Network Design
def OurModel(input_shape, output_space):
    X_input = Input(input_shape)
    X = X_input    
    
    X = Dense(500, activation='relu')(X)
    X = Dense(500, activation='relu')(X)
    X = Dense(output_space)(X)
    
    model = Model(inputs = X_input, outputs = X)
    model.compile(optimizer=Adam(lr=0.001), loss='mse', metrics=['accuracy'])

    return model

# Action Agent
class Agent:
    def __init__(self, env_name):
        
        # environmental variables 
        self.env_name = env_name       
        self.env = gym.make(env_name)
        # self.env.seed(0)  
        self.action_size = self.env.action_space.shape[0] 
        self.state_size = 6 #self.env.observation_space.shape[0]
        
        # takes action and previous state as input
        self.input_size = self.action_size + self.state_size
        self.output_size = self.state_size
        self.render = True
        
        # global variables
        self.rollout = 1000
        self.horizon = 30
        
        # training
        self.episodes = 200
        self.batch_size = 1_000
        
        # initialise memory
        self.replay_length = 1_000_000
        self.memory = deque(maxlen=self.replay_length)
        
        # model
        self.system_model_1 = OurModel(self.input_size, self.output_size)
        
        #analysis
        self.saved_rewards = []
    
    # decide action from state
    def act(self, state_in):         
            
        # reset the state and trajectory
        trajectory_value = np.zeros(self.rollout)
        state = np.tile(state_in, (self.rollout, 1))
        state = self.preprocess(state)

        for h in range(self.horizon):

            # select a random action
            action = np.array(np.random.uniform(low=-1.0, high=1.0, size=(self.rollout, self.action_size)), dtype=np.float32) 
            
            if h == 0:
                first_action = action  

            # get the combined state
            combined_state = np.concatenate((state, action), axis=1) 
            
            # predict the next state     
            diff = (self.system_model_1(combined_state).numpy()).reshape(self.rollout, self.output_size)   
            next_state = state + diff            
            
            # process the reward  
            reward_dist = - next_state[:, 5]
            reward_ctrl = - np.sum(np.square(action), axis=1)
            costs = reward_dist + reward_ctrl
            
            # update the state
            trajectory_value += costs
            state = next_state        
        
        best_index = np.argmax(trajectory_value)
        best_action = first_action[best_index]
                
        return best_action
    
    # unpack data from memory 
    def unpack(self):        
        
        # sample a minibatch        
        minibatch = np.array(random.sample(self.memory, self.batch_size))
            
        # unpack the data
        state = np.vstack(minibatch[:, 0])
        action = np.vstack(minibatch[:, 1])
        reward = np.vstack(minibatch[:, 2])
        next_state = np.vstack(minibatch[:, 3])
        done = np.vstack(minibatch[:, 4])
        
        state = self.preprocess(state)
        next_state = self.preprocess(next_state)
        
        return state, action, reward, next_state, done
    
    # train the dynamics model
    def train(self):
                                        
        # access data from replay        
        state, action, _, next_state, _ = self.unpack()
        
        # normalise the difference
        diff = next_state - state
        
        # combine action and state 
        combined_state = np.concatenate((state, action), axis=1)  
        
        # Train the Neural Network with batches
        self.system_model_1.fit(combined_state, diff, batch_size=self.batch_size, verbose=0, epochs=10)
    
    # simplify the features
    def preprocess(self, state):
        
        processed_state = np.zeros((state.shape[0], self.output_size))
        
        # process the angles        
        cos_theta_1 = state[:, 0]
        cos_theta_2 = state[:, 1]
        sin_theta_1 = state[:, 2]
        sin_theta_2 = state[:, 3]        
        theta_1 = np.arctan2(sin_theta_1, cos_theta_1)
        theta_2 = np.arctan2(sin_theta_2, cos_theta_2)
        
        # process velocity
        vel_x = state[:, 6]
        vel_y = state[:, 7]        
        vel = np.sqrt(np.square(vel_x) + np.square(vel_y))
        
        # process distance
        dis_x = state[:, 8]
        dis_y = state[:, 9]
        dis = np.sqrt(np.square(dis_x) + np.square(dis_y))
        
        processed_state[:, 0] = theta_1      
        processed_state[:, 1] = theta_2   
        processed_state[:, 2] = state[:, 4]   
        processed_state[:, 3] = state[:, 5]  
        processed_state[:, 4] = vel
        processed_state[:, 4] = dis        
        
        return processed_state
    
    
    # reset the state
    def reset(self):  
        return self.env.reset()        
    
    # load the model weights
    def load(self, name):
        self.system_model_1.load_weights(name) 
    
    # save the model weights
    def save(self, name):
        self.system_model_1.save_weights(name + "_1.h5")       

    # run the agent    
    def run(self):
        
        frames = []        
        for e in range(1, self.episodes + 1):
            
            print('Starting Episode: ', e)
            state = np.array(self.reset(), dtype=np.float32)
            done = False
            episode_reward = 0
            frame = 0  
        
            while not done:
                
                # render the environment                
                if self.render:
                    self.env.render()    
                    
                frames.append(self.env.render(mode = 'rgb_array'))  
                
                # train the model
                # self.train()
                
                # act according to the agent
                action = self.act(state)   
                next_state, reward, done, _ = self.env.step(action)             
                
                # update the replay
                self.memory.append((state, action, reward, next_state, done))                
                
                episode_reward += reward
                frame += 1
                state = next_state

                if done: 
                    
                    imageio.mimsave('./Images/Reacher.gif', frames, fps=30)
                    
                    print('Episode {} Score: {}'.format(e, episode_reward))
                    self.saved_rewards.append(episode_reward)
                    if e % 10 == 0:   
                        
                        # save the replay                          
                        with open("./Replays/replay1.txt", "wb") as file:
                            pickle.dump(self.memory, file)                            
                        
                        # save results
                        with open("./Results/rewards-ep-" + str(e) + ".txt", "wb") as file:
                            pickle.dump(self.saved_rewards, file) 

                        # save model
                        self.save('./Models/MB_Model')   
                        
                
        self.env.close()
        

# load the replay memory
with open("./Replays/replay_1_000_000_reacher.txt", "rb") as file:
    replay_save = pickle.load(file)          

if __name__ == "__main__":
    env_name = 'Reacher-v2'
    agent = Agent(env_name)
    agent.memory = replay_save
    agent.load('./Models/MB_Model_Reach.h5')
    agent.run()

# %%
import pickle
import numpy as np 
import matplotlib.pyplot as plt

with open("./Results/rewards-ep-100.txt", "rb") as file:
    a = pickle.load(file)    

mean = []
for i in range(len(a)):
    
    if i % 10 == 0 and i > 0:
        mean.append(np.mean(a[i - 10 : i]))
    
    
x1 = np.array(range(1,10)) * 10
y1 = mean

x2 = np.array(range(1,101)) 
y2 = a

plt.plot(x2,y2)
plt.plot(x1,y1)
plt.xlim(0, 100)
plt.xlabel('Episodes')
plt.ylabel('Reward')
plt.ylim(-50, 0)
plt.grid(alpha=1.0)
plt.savefig('./Images/MD_Reacher.png')

# plt.show()
